# %% [markdown]
# # Features engineer

# %%
from scripts.feature_engineer import run_feature_engineering
merged_dir = "../preprocessed_data/reference/1. merged data/without_y_100_one_side/"
cells = ["X1", "X2", "X3"]
META_COLS = ["gene_name", "chr", "gene_start", "gene_end",
             "TSS_start", "TSS_end", "strand", "gex", "gex_rank"]
marks = ["DNase", "H3K27ac", "H3K4me3", "H3K27me3", "H3K36me3", "H3K4me1", "H3K9me3"]

# === 讀取資料 ===
df = run_feature_engineering(merged_dir, cells, marks)
# Out:
# 📂 Processing X1 ...
# ✅ [gene_structure] All 2 new features valid.
# ✅ [tss_to_gene_boundary_min] All 8 new features valid.
# ✅ [promoter_gene_ratio] All 12 new features valid.
# ✅ [activation_balance] All 2 new features valid.
# ✅ [promoter_entropy] All 2 new features valid.
# ✅ [chromatin_indices] All 2 new features valid.
# ✅ [strand_features] All 2 new features valid.
# ✅ [cross_mark_interactions_v2] All 189 new features valid.
# ✅ [activation_repression_indices] All 3 new features valid.
# ✅ [axis_and_delta] All 14 new features valid.
# 🔢 Performing rank transformation...
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:223: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_{m1}_ratio"]    = safe_div(b, a)  # 雙向比值
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:224: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_diff"]     = a - b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:225: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_absdiff"]  = np.abs(a - b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:221: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_mul"]      = a * b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:222: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_ratio"]    = safe_div(a, b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:223: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_{m1}_ratio"]    = safe_div(b, a)  # 雙向比值
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:224: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_diff"]     = a - b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:225: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_absdiff"]  = np.abs(a - b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:221: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_mul"]      = a * b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:222: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_ratio"]    = safe_div(a, b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:223: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_{m1}_ratio"]    = safe_div(b, a)  # 雙向比值
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:224: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_diff"]     = a - b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:225: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_absdiff"]  = np.abs(a - b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:221: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_mul"]      = a * b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:222: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_ratio"]    = safe_div(a, b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:223: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_{m1}_ratio"]    = safe_div(b, a)  # 雙向比值
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:224: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_diff"]     = a - b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:225: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_absdiff"]  = np.abs(a - b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:221: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_mul"]      = a * b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:222: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_ratio"]    = safe_div(a, b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:223: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_{m1}_ratio"]    = safe_div(b, a)  # 雙向比值
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:224: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_diff"]     = a - b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:225: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_absdiff"]  = np.abs(a - b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:221: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_mul"]      = a * b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:222: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_ratio"]    = safe_div(a, b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:223: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_{m1}_ratio"]    = safe_div(b, a)  # 雙向比值
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:224: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_diff"]     = a - b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:225: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_absdiff"]  = np.abs(a - b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:221: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_mul"]      = a * b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:222: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_ratio"]    = safe_div(a, b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:223: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_{m1}_ratio"]    = safe_div(b, a)  # 雙向比值
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:224: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_diff"]     = a - b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:225: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_absdiff"]  = np.abs(a - b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:221: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_mul"]      = a * b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:222: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_ratio"]    = safe_div(a, b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:223: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_{m1}_ratio"]    = safe_div(b, a)  # 雙向比值
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:224: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_diff"]     = a - b
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:225: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_{m2}_absdiff"]  = np.abs(a - b)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:235: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m1}_tss_{m2}_gene_std_cross"] = df[tss_col_1].astype(float) * df[gene_col_2].astype(float)
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/3842387124.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{m2}_tss_{m1}_gene_std_cross"] = df[tss_col_2].astype(float) * df[gene_col_1].astype(float)
# ...
#   df[f"{prefix}_{mark}_tss_peak_density_times_bw_mean"] = df[tss_peak_dens] * df[tss_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_peak_density_times_bw_entropy"] = df[tss_peak_dens] * df[tss_bw_entropy]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:84: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_peak_entropy_times_bw_mean"] = df[tss_peak_entr] * df[tss_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_bw_promoter_gene_delta"] = df[tss_bw_mean] - df[gene_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_bw_promoter_gene_ratio"] = safe_div(df[tss_bw_mean], df[gene_bw_mean])
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_bw_bed_interaction"] = df[tss_bed_mean] * df[tss_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:99: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_gene_bw_bed_interaction"] = df[gene_bed_mean] * df[gene_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_bw_over_peak_density"] = safe_div(df[tss_bw_mean], df[tss_peak_dens])
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_bw_std_over_peak_entropy"] = safe_div(df[tss_bw_std], df[tss_peak_entr])
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_gene_bw_over_peak_density"] = safe_div(df[gene_bw_mean], df[gene_peak_dens])
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_gene_bw_std_over_peak_entropy"] = safe_div(df[gene_bw_std], df[gene_peak_entr])
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:70: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_entropy_diff"] = df[tss_bw_entropy] - df[tss_peak_entr]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:72: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_bw_vs_bed_mean_diff"] = df[tss_bw_mean] - df[tss_bed_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:74: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_gene_entropy_diff"] = df[gene_bw_entropy] - df[gene_peak_entr]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_peak_density_times_bw_mean"] = df[tss_peak_dens] * df[tss_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_peak_density_times_bw_entropy"] = df[tss_peak_dens] * df[tss_bw_entropy]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:84: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_peak_entropy_times_bw_mean"] = df[tss_peak_entr] * df[tss_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_bw_promoter_gene_delta"] = df[tss_bw_mean] - df[gene_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_bw_promoter_gene_ratio"] = safe_div(df[tss_bw_mean], df[gene_bw_mean])
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_bw_bed_interaction"] = df[tss_bed_mean] * df[tss_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:99: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_gene_bw_bed_interaction"] = df[gene_bed_mean] * df[gene_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_bw_over_peak_density"] = safe_div(df[tss_bw_mean], df[tss_peak_dens])
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_bw_std_over_peak_entropy"] = safe_div(df[tss_bw_std], df[tss_peak_entr])
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_gene_bw_over_peak_density"] = safe_div(df[gene_bw_mean], df[gene_peak_dens])
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_gene_bw_std_over_peak_entropy"] = safe_div(df[gene_bw_std], df[gene_peak_entr])
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:70: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_entropy_diff"] = df[tss_bw_entropy] - df[tss_peak_entr]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:72: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_bw_vs_bed_mean_diff"] = df[tss_bw_mean] - df[tss_bed_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:74: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_gene_entropy_diff"] = df[gene_bw_entropy] - df[gene_peak_entr]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_peak_density_times_bw_mean"] = df[tss_peak_dens] * df[tss_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_peak_density_times_bw_entropy"] = df[tss_peak_dens] * df[tss_bw_entropy]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:84: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_peak_entropy_times_bw_mean"] = df[tss_peak_entr] * df[tss_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_bw_promoter_gene_delta"] = df[tss_bw_mean] - df[gene_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_bw_promoter_gene_ratio"] = safe_div(df[tss_bw_mean], df[gene_bw_mean])
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_tss_bw_bed_interaction"] = df[tss_bed_mean] * df[tss_bw_mean]
# /var/folders/7g/j5s0yzcj34l3v043s7znkplc0000gn/T/ipykernel_28501/1023505961.py:99: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{prefix}_{mark}_gene_bw_bed_interaction"] = df[gene_bed_mean] * df[gene_bw_mean]
# ✅ [advanced_chromatin_features] All 15 new features valid.
# ✅ [cross] Added 98 cross-layer features.
# ✅ Saved engineered features → ../preprocessed_data/reference/1. merged data/without_y_100_one_side/X3_all_rank_features.tsv
#
# 🎯 Feature engineering complete for all cell lines.
